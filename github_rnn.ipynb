# %%
import numpy as np
class Data:
    def __init__(self,path, seq_length):
        self.fp = open(path,'r')
        self.data = self.fp.read()
        character = list(set(self.data))
        self.char_to_index = { ch:i for (i,ch) in enumerate(character)}
        self.index_to_char = { i:ch for (i,ch) in enumerate(character)}
        self.data_size = len(self.data)
        self.vocab_size = len(character)
        self.tracker = 0
        self.seq_length = seq_length

    def next_batch(self):
        input_start = self.tracker
        input_end = self.tracker + self.seq_length
        inputs = [self.char_to_index[ch] for ch in self.data[input_start:input_end]]
        targets = [self.char_to_index[ch] for ch in self.data[input_start+1 :input_end +1]]
        self.tracker += self.seq_length
        if self.tracker + self.seq_length >= self.data_size:
            self.tracker = 0

        return inputs, targets

    def reset_tracker(self):
        return self.tracker == 0

    def close_file(self):
        self.fp.close()

class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate

        self.W_ih = np.random.uniform(-np.sqrt(1./vocab_size),np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.W_hh = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./vocab_size), (hidden_size, hidden_size) )
        self.W_ho = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        # self.W_ih = np.random.randn(hidden_size, vocab_size) * 0.01
        # self.W_hh = np.random.randn(hidden_size, hidden_size) * 0.01
        # self.W_ho = np.random.randn(vocab_size, hidden_size) * 0.01

        self.h = np.zeros((hidden_size , 1))
        self.o = np.zeros((vocab_size, 1))

        self.mW_ih = np.zeros_like(self.W_ih)
        self.mW_hh = np.zeros_like(self.W_hh)
        self.mW_ho = np.zeros_like(self.W_ho)
        self.mbh = np.zeros_like(self.h)
        self.moh = np.zeros_like(self.o)

    def soft_max(self, x):
        p = np.exp(x - np.max(x))
        return p/np.sum(p)

    def forward(self, inputs, hprev):
        xs, hs, os, ps = {},{},{},{}
        hs[-1] = np.copy(hprev)
        for i in range(len(inputs)):
            xs[i] = np.zeros((self.vocab_size, 1))
            xs[i][inputs[i]]= 1 
            hs[i] = np.tanh(np.dot(self.W_ih,xs[i]) + np.dot(self.W_hh, hs[i-1]) + self.h)
            os[i] = np.dot(self.W_ho,hs[i]) + self.o
            ps[i] = self.soft_max(os[i])

        return xs,hs,ps

    def backward(self, xs, hs, ps, targets):
        dW_ih, dW_hh, dW_ho = np.zeros_like(self.W_ih),np.zeros_like(self.W_hh), np.zeros_like(self.W_ho)
        dbh, dbo = np.zeros_like(self.h), np.zeros_like(self.o)
        dhnext = np.zeros_like(hs[0])
        for i in reversed(range(self.seq_length)):
            dy = np.copy(ps[i])
            dy[targets[i]] -= 1
            dW_ho += np.dot(dy,hs[i].T)
            dbo += dy
            dh = np.dot(self.W_ho.T,dy) + dhnext 
            dhraw = (1 - hs[i]*hs[i])*dh
            dbh += dhraw
            dW_ih += np.dot(dhraw,xs[i].T)
            dW_hh += np.dot(dhraw,hs[i-1].T)
            dhnext = np.dot(self.W_hh.T, dhraw)

        for dparameters in [dW_ih, dW_hh,dW_ho,dbh,dbo]:
            np.clip(dparameters, -5,5,out=dparameters )

        return dW_ih,dW_hh,dW_ho,dbh,dbo


    def loss(self, ps, targets):
        return sum(-np.log(ps[i][targets[i],0]) for i in range(self.seq_length))

    def update_model(self,dW_ih, dW_hh, dW_ho,dbh, dbo):
        for param, dparam, mem in zip([self.W_ih,self.W_hh,self.W_ho, self.h, self.o],
                                     [dW_ih, dW_hh, dW_ho,dbh, dbo],
                                      [self.mW_ih, self.mW_hh, self.mW_ho, self.mbh, self.moh]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem + 1e-8)

            #adagrad optimiser

    def sample(self, h, seed_ix, n):
        x = np.zeros((self.vocab_size, 1))
        
        x[seed_ix] = 1
        # print(seed_ix)
        ixes = []
        for i in range(n):
            h = np.tanh(np.dot(self.W_ih, x) + np.dot(self.W_hh, h) + self.h)
            y = np.dot(self.W_ho,h) + self.o
            # print(h)
            p = np.exp(y) / np.sum(np.exp(y))
            # print(p)
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = np.zeros((self.vocab_size, 1))
            x[ix] = 1
            ixes.append(ix)

        return ixes

    def train(self, data_reader):
        iter_num = 0
        threshold = 0.01
        smooth_loss = -np.log(1.0/data_reader.vocab_size)*self.seq_length
        while (smooth_loss > threshold):
            if data_reader.reset_tracker():
                hprev = np.zeros((self.hidden_size, 1))

            inputs, targets = data_reader.next_batch()
            xs, hs, ps = self.forward(inputs, hprev)
            dW_ih,dW_hh,dW_ho,dbh,dbo = self.backward(xs, hs, ps, targets)
            loss = self.loss(ps, targets)
            self.update_model(dW_ih,dW_hh,dW_ho,dbh,dbo)
            smooth_loss = smooth_loss*0.999 + loss*0.001
            hprev = hs[self.seq_length - 1]
            if not iter_num%500:
                sample_ix = self.sample(hprev, inputs[0], 200)
                
                sample_text = ''.join(data_reader.index_to_char[ix] for ix in sample_ix)
                print(f'{" " * 500}')  
                print(f'Iteration: {iter_num}, Loss: {smooth_loss:.4f} ')
                print(f'Sample: {sample_text}')
                

            iter_num += 1

    def predict(self, data_reader, start, n):

        x = np.zeros(self.vocab_size, 1)
        chars = [ch for ch in start]
        ixes = []
        for i in range(len(chars)):
            ix = data_reader.char_to_index[chars[i]]
            x[ix] = 1
            ixes.append(ix)

        h = np.zeros((self.hidden_size, 1))
        for i in range(n):
            h = np.tanh(np.dot(self.W_ih, x) + np.dot(self.W_hh, h) + self.h)
            y = np.dot(self.W_ho, h) + self.o
            p = np.exp(y) / np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p=p.ravel())
            x = np.zeros(self.vocab_size, 1)
            x[ix] = 1
            ixes.append(ix)

        txt = ''.join(data_reader.index_to_char[i] for i in ixes)
        return txt



seq_length = 25
data_reader = Data("saks.txt",seq_length)
rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size, seq_length=seq_length,learning_rate=1e-1)
rnn.train(data_reader)
# Out:
#
# Iteration: 0, Loss: 104.3597
# Sample: Bhn k'Rl.Nnwsn ppntn!G!dcuzopzprpHMASlR&tr
# oon
# rXodHx;$tonfsnpo yWE'$Wsprn
# :pnwB,k!JJQnn rii:CoP-lW.yQVorzn
# :
# 3cWM.NRn:wnBfGnvSqVNKtenrfnrp oHQgJkOC
# en pnff&N.Qv'sepwwpJIBvAUEazf mip:r:wq-cKUJonp annr
#
# Iteration: 500, Loss: 99.7128
# Sample:  . h teho dadirs.Utjip
# rUr  o.ohyoen.c XPl
# uCebqoeat'ileli!iyolt-e ae orlo a b
# BeolnraWhnm
# MeoMi UueOse
# nty t m;   n.aA  tl thfdno eOi
# hvtmtahunHrd?at tngs escCrpi l i ni!W F  .FJat&oh:S Is
# F  ?o nmwi
#
# Iteration: 1000, Loss: 93.4119
# Sample:  sibNs n  d  aTee i
# v
# ohece
# fiosoanah tiw Wo hqbw
# ey hashiIdfeogrUth eh  mfi wliIoiw-
# rk e anh o,s
# nHk A 'Lhd he
# toh:  eoe
# rrHer$ e nxmeNm uaeRiZln&lhoJkepuf uY,:M net
# tOo,  fd.yheiuee   attee,hspr -l
#
# Iteration: 1500, Loss: 88.1675
# Sample: tagoasLkseli. snddhlt hi,
# rde e tioydeint .oXc FteSa hfhsWsonhirerlwomheoF, e wyi thaT  fhiret roor a coo,it'iw sinhhi rthl d h It
# X: agu e ta; :
#  etc'odlva.
# lre ifch N vfi?. e
# oulin ys tetoi,att panr
#
# Iteration: 2000, Loss: 83.5779
# Sample: tshe nlenu w
# ReK, enheges v eulwerd
# in-n ud Xulivefite hotI rnWhTelmnornUSr,n la Vmereuk ma; gurtool nsl. yoo :
#  d o helleu heuM
# TeaMSs huy e onreldCTUye'rar hlhee
# miuUev r, ;  oAn cirnosaus hxhUee he
#
# Iteration: 2500, Loss: 79.7917
# Sample: orffontt nst cieTdonuud wuTheu MchFkeq
# Shehd ielLNumirohhete oors se
# Nsres
#
#
# Ti
#
# FthGyinrhi wihe
# ly beSe yinbak dis plthe a:uTthprdsoi thsn :
# s :
# atanh on. r co
# Tro ole cl wilenhhe p:
# sa th,ri'loadeid
#
# Iteration: 3000, Loss: 76.1697
# Sample: nratsroe i,
# thosthve tsam  t hotraIRITI
# ttoy o tha!
# Mbea shiwocanriy henishe.
#
# TStotidim bitsO yhanemireg oDme
#
# recotd eom v yreLs theu; dh hhilks okeERSy ilra theTra Olsinu atowane
# encbess  onestn se
#
# Iteration: 3500, Loss: 72.9200
# Sample: d.
#
# UShd aheucepot s phiFa l, lu I ber tos'sbe wras ta nhiweI koyt heltvior gumheld vesrALanshSiBs heeusd sfjy sh touds shhet, yre tle whas aat I ifaghe the
# ko crey ad due r i heusrle rotrosg dolaotn
#
# Iteration: 4000, Loss: 70.2056
# Sample: hol wopd riwy aa nolinulmm afg iet af.
# AeMt ve sot iephe meete,n
#  hryort
#
# RS:
# Clechaoe rew kweId  ai s sul'-velotcinsrhrru riut,
#
# lRAss be kous
# A
# krowme espuY's wo's dof
# Imestins ton aeit thi i ir th
#
# Iteration: 4500, Loss: 67.9896
# Sample: aer bike ve ei dhe doft n, the o't musanbeove herkene seros .
#
# Thent pitmee
# de thd nos phlalld Anlla co ins  tsterl ce.
#
# Tard! sd y, is oust moundy tot whe, se he hllathe
# Syr hat want themuavo han?
#
# t
#
# Iteration: 5000, Loss: 66.2127
# Sample: lisiflls heS:
# Cnet
# MMamd mandoshensu.
# F:
# wo fals bautas, Ashan tisanis wesau?e nhirse wiseir ass mas had fslre had , abw hinn,.
#
# Ogil hie shg y!Te oe ejtary azwe fisonouds fret! sid fuubannceds nof fs
#
# Iteration: 5500, Loss: 64.9385
# Sample: cues hoesin ctinatx
# To luoogwi af, wior!
#
# Teensr
# I IThn the lapret thhint mas ty.
#
# IOUIULly t mhit torisnmed taske nif ourses aame bist aon ate  oss ut p, fhin,
# L'p, er'gol is da ceishek:
#  Sers:
# Chole
#
# Iteration: 6000, Loss: 63.7197
# Sample: ld unt fenuud phlon'd, bid,
# pous the werep:
#
# NIthirirdres.
#
# CiWhend ITorlf hirthene
# LIORCUS:
#
# Fad wad ve s doref wou sird aal?
#  oml
# IS:Rd eo titi: det
#
# lthe.
#
# 'Tbourhe as,
#  ArrrBis ow fowe'dsr the  hh
#
# Iteration: 6500, Loss: 63.6200
# Sample:  ores hes ar's wryor that the Ilardlank ve wo ory me sill ollrseek mi. hand
# Thin :
# th touus, I
# Temo Aceaceerpanlm oan hth.
#
# Fhet
#
# W, ,h.
# Thim merstherthengthd, tior llg.
# AELII beotid wrole hik tall e
#
# Iteration: 7000, Loss: 63.0882
# Sample: u go ,
#
# Thin heng whd:
# S:
# DGUB:
# IId taxsTsiot fotthtt ild hoan tirs,
# I
# Ods spleMs:
# C
# LSULNY
# Houn diwt Cras
# These storwor uy iwtre thasend go do aner bpmo pe.
#
#
# Fhof IDn Her ar, ghile ave moumand mone
#
# Iteration: 7500, Loss: 62.5041
# Sample: en! fhy, wrue thote mecfshy thonir or,
# Vounnpo wo wul youeekeas rat fhasid the Hiceh:
# Told
#
# GGeEId corpoasilii;
#
# LGNNUERU:
# QVTGare lit-the,
# B,
#
# MANEAETs ak',
# Thouss gubeser bupi po nrome dnoupstetiegt
#
# Iteration: 8000, Loss: 61.6963
# Sample: ENOthos ; to thaads, urves neth mseveonl s abe?
# Hpet:
# Tiwe wont, ther, ore yor-usd,
# ThiclofveseThoun: pour; be. bing sef mo Merarthus Yols bseve.
#
# GbRude hiby ten nart dou deesed nts urnnt ark, sader
#
# Iteration: 8500, Loss: 61.2238
# Sample:  doR yhofurvete yoit cas ian esndmbe hill wicgers, at-y wannd moy thed wandyiusc fhagave frestoy arit acwegrete Serrevik fis, l oue fub.
#
# AOROGCEN:
# Whad ji:
# Fose fothble, doun he gheith he somad s so'
#
# Iteration: 9000, Loss: 61.0742
# Sample: ontiws allen boathas.
# Fas wond,
# The bsien tametw foe, wild Ao'Ft nouss the, as weng inhe,ur langremamaf wipmar kon as toultilnty Ther martey dot sliend srawsse kuly, thent as:
# : no ipmon thell womcety
#
# Iteration: 9500, Loss: 59.7644
# Sample: s, fo ghot Arlid ta laen herongeu hperevenin gouse
# Hing kir, Mr:
# Wo.
# And mod, eny thoo mith you, bitsat thoust.
#
# Qmy, lrerss, peres foul, fon morir.
# Wo yey urt ous, in oofghes whas dot hol yont thouk,
#
# Iteration: 10000, Loss: 59.1802
# Sample:  tratamy bake trer of fomt woun ou tes sadth ener pordren rast is, cod oucest bopkeen whe the hgauis thane pae satat weand p'deatd net has,
# Whinnd
# The lo yoalg,
# Sot sha, trat fous afcand core oud, pad
#
# Iteration: 10500, Loss: 58.8429
# Sample: :
# B Euceesnewin tain, witymort toe teporeis roggeiUTodarl oaden the your thre soetin he! man.
#
# Fes how bo wontthel If,
# Mocemd carll teanen to hnose bes orim serind of I.haunvepardes at, mapfiry, wyouc
#
# Iteration: 11000, Loss: 59.3991
# Sample: th bron iatw's and sarpco Eill twiWe
# I Ther t  iarste
# I IZs borellg corces, wewan: I heung maRblt Ig namt tomel by cis'l sen:
# By thas is't congh hy's blind peic or overn agald ghit noy share crore nou
#
# Iteration: 11500, Loss: 58.4884
# Sample: As hy mat thabAld epeem trodti fleise, dour.
# S'di te, frather he a dis?
#
# He bectath tamer ota sast, lithe lily roon thoun- shory nad ance ontues thof mat cimand lyshoudlat?
# Aly barezake
# Heilaf, trr ti
#
# Iteration: 12000, Loss: 57.9978
# Sample: derendp kerr heshen blow whiN fumey oul, the quer?
# Whe shen snas of, grthand haa in?
#
# Q hopelqere
# O co ant all wiving.
# Thot my bouthe rover er co wnore foU, win:
# AUt ARACDUENZIELUSHh Tho tond qeim
# Prr
#
# Iteration: 12500, Loss: 58.5002
# Sample: LH:
# Ghact ind angesandem terlveore nomiswt maden;
# Dof their niterd ke :
# y
# Antw hats, o'k.
# Lane hos thach hind we fery for;- you ze byon our my.
# the lore
#
# HId:
#
# QUF
# DIWhire, urdti, wte mew noens of wen
#
# Iteration: 13000, Loss: 58.5992
# Sample: actoer; forers me for wall sngauce.
#
# Thit Of:
#
# ARD:
# And enst isy fougsomard woond u, eor wistece's Ror or.
# Mrimey de'd the fuw;
# Non to
# My don hich os ut ithle op shito archewe foupd, preandeofonte; wi
#
# Iteration: 13500, Loss: 58.6502
# Sample:  amrerarlam.
#
# IESAs
# ACICDe:
# Marnthang mar irnot nor.
# Q fitht wele,
# Wof.
#
# Qot ingh speroudcenveis hatnersine fen, aared,
# My cienas gorees,
# S:
# Maede serancd the,
# kiN IOICEN:
# Res laroldpin Burin tion fna
#
# Iteration: 14000, Loss: 58.3377
# Sample: thate, nor yoloflh BriWhave boog alks bekl tsith ffuty wavome ish Teave I trai hange to
# Whet atcancorr touvenq
# Lisstiprath Pous.
#
# Yreourdes sminis shaat bphis
# Feinds, th he thas theese the jith domant
#
# Iteration: 14500, Loss: 58.0618
# Sample: f tour loft, thouphor savee pucind hat;
# Whors, yoush bang, elr fomy, in I bnoor hi, to h mos fouf whe ge I ton Gok due nos wasihi -ou liwamm fioc he, she thagem thore-n-rinoke dre poukin afr in fatheh
#
# Iteration: 15000, Loss: 57.6961
# Sample:  doy IJ mless fourrd wies to Rhes ifu fasin as moodh Brd,
# BRLINRYouth fos sheo wabfor, nhas at thee saeyi:
#
# idh- fepaccom,
# Tale the siel INGBRTIINT:
# My divep gouen,
# Thot en le ofor ou worthy Bat aick
#
# Iteration: 15500, Loss: 57.4982
# Sample: n with be igU, walthvy.
#
# ngazeighse sashsisher sela cell andtighuth;
# Bave glorgwano le't tiAst deavingi withand theameig
# Mo epiw?
# houge may me iwi ounw northe sorkefroungy
# An bemider ath mes tu id co
#
# Iteration: 16000, Loss: 57.2840
# Sample: neke thad berstounee, meeds;
# dose wey dires iurlm shersith soun wiet Nobe me staste of tharl theth phVered; cust kaen,
# Y,
# Whand ware hes Your young benbity stonoas.
# un,
# AG we jowobe,
#
# BOKENGWhwaln hes
#
# Iteration: 16500, Loss: 57.0499
# Sample: bleis kowm be thimtid that molls him brele oisbwoag pot lisslit serth y piss thor wey reat gamareoc rim now shotw
# Sibe heaobl.
# Th mus coilingay ererd'n tore fere ofte teor mest be, forgeng, brot coce
#
# Iteration: 17000, Loss: 56.4199
# Sample:
#
# KI ini ay more espeldesgarpeke teaghamind genget youkceechenplat, ameate t!porredpe mat on th amspreblaks mosnis lind thinee!. proul trize hop hee thand!
#
# D ho kemy me anderst lo rhibmcere.
# Tratd in
#
# Iteration: 17500, Loss: 55.8850
# Sample: heass that nole way atharl' s ipins!
# Bow thelkerd.
#
# HOLBES:
# Nn:
# Powr thaaseinc mit he, ay whe leThe spreke
# Thowe ke thoult:
#
# KNGOHERNTOBRH:
# TOJta tith mathergh Thouth hiande the ous wichine you:
# And s
#
# Iteration: 18000, Loss: 56.2864
# Sample: Thy;
# T's
# F weut-ricke yothuthed hous bno the srarineer werld
# Hedirst cuintniw buthsur and:
#
# KENO:
# CKO EONGIRS:
# The I sees sois chas pe tiwentthif asi, noand.
#
# Wiid id seal thelds ind ? Cuomy yourssely
#
# Iteration: 18500, Loss: 56.8904
# Sample: weais oucalke :
# Gore skel:
# Averime mer: hiring.
#
# LI:
# Heum, toepreonde houl is of ayeve tho say, loun:
# Agy keld clou bers anino thit meall thand munt os ink cats and!
# frardeld ave thaj sthavt thyty upa
#
# Iteration: 19000, Loss: 57.2344
# Sample: thou he.
#
# ABtI:
# And:
# Thith buse Hadd
# ANUEI:
# Ay, hetr, fith my coblang aftno, taele gering the-, ches.
#
# MRBELO tigh way?
# she atken ung bowey, dat Hiins cetich; be hasd tay sint.
# A!
#
# ONGCHO:
# M:
# Ta ir ra
#
# Iteration: 19500, Loss: 56.6260
# Sample: emay dnifd
# TF onit, err'lind thy wine s tint the haco fand thichun sot prongu'gd amepe.
# I-rell is will, songod svel dathen's mull 'sirndsns st, thou ham angt ad harkendang trothy aveouthencreedish.
#
# D
#
# Iteration: 20000, Loss: 56.6246
# Sample:
# Then alin sry xim, ur to is as
# BUMERD:
# Thod arl thouris ay.
# Wy deas theod'd.
#
# MEO:
# I wereltact thus ynood.
#
# Acge:
# Axit yond'b-hge, tict Is,
# That atict and whish.
#
#  OFETh tmeccom meero, and hound file
#
# Iteration: 20500, Loss: 56.9322
# Sample:  thabsirey we tol siy, Al.
# By lo you mep iw, mevisher constithmat ouromofalu:
# Fstouchlle mag as miscrely dost:
# Whet me ine tonweldss hano ant, that his fy.
#
# AM: Orincawsed turipe of thay' I hom stlik'
#
# Iteration: 21000, Loss: 56.9863
# Sample: ll cay anculneresh we lece weak dy nof reonor mads owde?, gut thet same wircas whant, bamimla, in, cain. Hiner fo sea psirnas? and:
# Loge:
# How tu whin': trir mals sok oll aind herl,
# T;
# Burlot shint,
# Bo
#
# Iteration: 21500, Loss: 56.3472
# Sample: h;
# OR ouke have tereeant it mairenos thall ko duyied of ot lonee  iill 's, myse ueren astle ghi? eke me bish'f thom sith.
# Thaks lt lerint to fon of ly daUs dotjen's dank!
# Hithed, An yory
# thrrey;
# Bouus
#
# Iteration: 22000, Loss: 55.7857
# Sample: r; uthilg bardnquse feat
# my inst,
# Famy ay hond thall ou,
# Thar ox fike is forentather por sampensass, mirer ink,
# Wheng ir harerind be boy stow at troare reall
#
# RIJULIET:
# Yol ongt I'k gane! tharn is my
#
# Iteration: 22500, Loss: 56.2028
# Sample: ndry.
#
# Cith saf feeles en soly mhas!
# I thad
# Wo suks and she.
#
# AENRALI:
# Ay ey tilir
# I hatrer tham I Or huthe.
#
# FARI LEitstover to fotode and, ge foraththte in nawif
# A:
# CJo he the. aty ist, cravece.
#
# HA
#
# Iteration: 23000, Loss: 56.0058
# Sample: nes ether!
# G antte wores ars: co cam codw wat I ang-hant mes, Spo, fon thel wireye thuth'lh ne go
# Ror, fofoak co hare sheurd, hufl ho troth hen Mith my gok frear nous'n wrebisk whlo is rall wite sam,
#
# Iteration: 23500, Loss: 55.8211
# Sample: f thef Int Lead: thom ty mes;
# O veard fore brould kis ke offoror ing perpye?
#
# FCCoon I:
# That my wale sufn lthit burg yof;
# ThiR my:
# And int deon the lithe
# S I's the hif what thove tturidnill cind ynas
#
# Iteration: 24000, Loss: 55.6290
# Sample: u thrindt I ktnoon anst prowos.
# No,
# Awire, bich beat pard to how the she mo hime kongs me I cxieond.
#
# LURY
# YUn Baldends, in tU mint liddert.
# A thad kis on all deardt them phis sthall liy'd gumeon sWot
#
# Iteration: 24500, Loss: 55.7283
# Sample: , wearn mask!
#
# ANPAGLAULdingor food co! nor,
# Nor the dind it aares, anl, thud cro: ann the hod thnwim a co dond be is shelk youl quy forth.
#
# KOCE:
# Hhe me at punce my whoun wire if wors ofr tour, loand
#
# Iteration: 25000, Loss: 55.1081
# Sample:  aur;
# Sy your dour.
#
# FareTh:
# He he lidt yo, thet f lath ur,
# Foo dich thatt creny pad ton: ou her atuga he
# Goth elir?
# Hamp.
# Thath stat taviey stave, tho t:
# It waveightingel hrair, hourse, veagt nan, wo
#
# Iteration: 25500, Loss: 55.1003
# Sample: el lisce!
#
# RIK:
# I lunw wies the yonoou singl Hereand teme be harce Hife, at Ro boom ben;
# A thow kichy veiifeecing have Youns! to wort han, crils boge;
#
# JIUK:
# And het wbof ant nou ho teker,; th now sow
#
# Iteration: 26000, Loss: 54.7125
# Sample: re trall rat pewin thart:
# The tey tive,
# Noim ado;
# And llrif.
#
# RAND oa he
# And of Jich lontgold
# Werife lisouch, usceam ouke shark dsYodea, I lo brore dow ghite hif tham daby lo I fharfavorors;
# I:
# Shir t
#
# Iteration: 26500, Loss: 54.8217
# Sample: sdes althasd, bewincom wuld.
#
# Kipt thas tatsthoo thines fertuss dopked thoulcrlysargirlly'q ard, doumy, my'd thang Eall gore.
# Ther s
# EEO meth mend atis's wimiteds,
# And and, thand I
# Hlit and tals'l cow
#
# Iteration: 27000, Loss: 54.6662
# Sample: t oinge, is od and vigat yow go yo deerey my grou,
#  LAPORED:
# Fo ille mev tos fope's, kiptcoot bow ol in yo gotherdver:
# Ramy salje of
# An I's one nishersteene buws'f wichercherery mor, sourdand.
# Ant ham
#
# Iteration: 27500, Loss: 54.5029
# Sample: oare.
#
# WICCEy: Wurromg and is 'in wow, tereils Heur is
# And hit ?
#
# KaRe eapdtis sin.
#
# GGINMRD:
# Porge time thave aus of ly worl,
# How for and t.
# No cadengeow sto cey in sor thas foms in, cordedsn ayhe,ot
#
# Iteration: 28000, Loss: 54.3635
# Sample: :
# O they  II s, lele bouthire ow quent dave ats nore,
# Now thy de;
# Naml ses; thigen bor im as farak is kervins.
# Wha kint sar of-lokparkige deedeld:
#
# Mo bfitnrus vearn, pullvireg waadt gurtpe lake a the
#
# Iteration: 28500, Loss: 54.4704
# Sample: fil, er, thy more urus es wicak not vis thoud thon In merus migh, my srordear on now thou beamined, the melfayein tuseid wtis erdiden be thoum,
# Nhat' sfoye thisk ouf With botend tot, thom is dith pral
#
# Iteration: 29000, Loss: 55.4399
# Sample:  thert
# O my. sthald palli?'y
# And nor mathur hewn' that oum stars hiser suld, andss
# Als,
# Dist; marise orrint thisglangeeol to thein to the mis my to qu the nower
# Youle puthy, Ang In the be the
# lasd why
#
# Iteration: 29500, Loss: 55.6529
# Sample: cesfnt: bretule crotth, your, berotheret wave che noms ho kiln has then ant our of ars: heack hay topcumnhis note and's thor mo bes.
#
# MIECLTEORERD:
#
# OLEINGR:
# Wham and thes wavoo ce noul aty, coungot o
#
# Iteration: 30000, Loss: 55.5616
# Sample: N:
# Hadid to ailidsice conge ho hokWen, phe as youme I II the wore
# A, to he
# Fhont mavexs ofst be llel,
# I thek thoumy muser Gak sim acke.
#
# CLEWAS IVNO:
# Le, yourn a the bhilt you dathy ind mercird
#
# HAGDO
#
# Iteration: 30500, Loss: 55.3638
# Sample: ane threar ensingangur, thachse coriberose tharg gow herwenin and aitarich o pip;
# Adeds shlr dore ang'st; ffourng He fhis ney shaccengweng crast
# Ald samifourn,
# OW,
# Of mef?
# Bas of the tist
# Pucwond nwir
#
# Iteration: 31000, Loss: 55.7173
# Sample: deans, arty to
# Aee ghishis: goou Pome po-lhath go thicers, be baviluldacd the toi and macoug lamamy, hese Loroee, s rgaith in an
# is ther efreaw'f ghautle'genseer,
# Wsie bidiss mer. tuegurs tu braken; w
#
# Iteration: 31500, Loss: 55.9254
# Sample: doue:
# Whe none anct mexerind arn
# Novespith it the I trotie, blo fcang spriur thrues int my if he.
# Pakel thit cFeeld
# Ailn grouch to loch.
#
# Po shimy sher'ster
# Is, wousn open pour Levesg, at Icusildd now
# ...
# Iteration: 807000, Loss: 46.8465
# Sample: ne a ine, why now 'numince to que?
#
# Well have no, uneds; dut be sou of't dete in that, to the come.
#
# GRESNAY:
# Nishould etes so peresty go urkend hip to wose O vel'st your bewor the savinow, and pleay
#
# Iteration: 807500, Loss: 46.9540
# Sample: chatieffe, you for of which she wertide:
# I know thiel, unastenot wold repth, enous thou: may mood on nown reeve chatite aptly tome
# Ox are ox thou ofamp-beot your et this do, five and goodse, me the:
# F
#
# Iteration: 808000, Loss: 47.0384
# Sample:  moufter, beolfope houch,
# I than shithas to wh prood kin'd
# TVush ceet wordst, fain bo, Grich Rusdise's a as 'tack morises, it,
# And wenteningled of thy eal here
# The carger't whetray, bice heavesteaind?
#
# Iteration: 808500, Loss: 47.1676
# Sample: how;
# Lord, ady notiter boke he lords?
#
# SHOMERIO:
# Noul stopyt dord are.
#
# Wionguts, our muther him stembing diding cundy, hough sald ro do but prook thew hime,
# Lucit'd, newince chordpres:
# The wat faif?
#
#
# Iteration: 809000, Loss: 47.5688
# Sample: ,
#
# ERCYIIANU:
# O to him litersed!
#
# Cout thane nepmby Sare, you it him. gith:
#
# COMEBARUMOUS:
# My bulded force
# And mas; I mimerd; wo shath so Poor: march he age driate a'll chice leas at;
# Have casplace co
#
# Iteration: 809500, Loss: 47.8900
# Sample: HEDwLIUS:
# The whict wonturcind.
#
# WARISS:
# Yeed pommones sweat me have os uned:
# To how is combe;
# What lut Hatcus chastarcore town
# Elvizean's of fiessell be tound, pethen voses and chacla, bity Souss the
#
# Iteration: 810000, Loss: 47.3472
# Sample: n I pot the of wor compen'd that leter, com?
# Go
# bus,
# The vave ye hal the ceast af ath sie theiv, contomen, but Ropfercy.
#
# GLOUKE you; all
# Sefpred bringe shay jostine?
#
# POOThe kpor fathang bid, cort, a
#
# Iteration: 810500, Loss: 47.0371
# Sample: p thou oll word this tad jece,
# Thes, Is
# Of be
# Ctome
# That all thedes, surt ars amank namby, shall othil speldersed, him tis, yet be decing:
# What of a dele;
# Whny you:
# Wile is houl anind thy the bech is
#
# Iteration: 811000, Loss: 47.3344
# Sample:  mess
# Bucs a whellsh nould As markess it a marraun this a penterid:
# Tene palst, you in?
# In prrowpy
# And wirt wifusts but diase, will of I that fill of that seer bucdardy. Whthein's the ining striste!
#
#
#
# Iteration: 811500, Loss: 46.9449
# Sample: enk your,
# mour it wirk.
# Hat that mys didleded bienof hew and on will boarve,
# Hould tabred, it enthas angcther. the dridy in thimuctorenesder whell ant,
# For bestontmamprader!
# Onp he'flle days outhale-d
#
# Iteration: 812000, Loss: 46.9395
# Sample: r?
# Campnen! in heacting; comad:
# Tiat
# At my he, then thow the of mich spathe''t not lontt call what in mluingress, fare shoud wissees fromeang, hath of Ries,
# And trizes woul soone, I fort to peas to pu
#
# Iteration: 812500, Loss: 46.2446
# Sample: esul the melie frir singor; a gay, a confid,
# And most
# A ivengy, to will to threncpecaipwencher as crubcery:
# Rime befern!
# Lerider.
# Our, she it her to know tnou where whatwly should litce lirpcenuss moi
#
# Iteration: 813000, Loss: 46.4116
# Sample: d will cour:
# Cour not:
# Lester.
#
# GLOUCESSET:
# And I pathelfore. Myos their of ot moy?
#
# GLOUCESS OF ORICHA:
# For uctit twend thin I wor to chey.
#
# MSCULEMR: plobe.
#
# Firise viron less Jused Go, menammarjest
#
# Iteration: 813500, Loss: 46.6959
# Sample: d,
# You gnepe ot canese, so now booke, fromble from live rawed there mist I hee! I selpo-thou to the you, why greme;
# And a morrush, swees thould all
# Bur roves,
# Belvert unourtelld, an greer a ownine:
# Be
#
# Iteration: 814000, Loss: 46.6919
# Sample:  pread bigueder;
# To Veriee more verienel's is to a alfor, it twen thum int sish;
# This of wee lood fues what lerety hish my day,
# A ney beghipenfleed this sit,
# What eald incent's tren.
#
# QUTEDWIIGS:
# Not
#
# Iteration: 814500, Loss: 45.9320
# Sample: ETr:
# Mat ethest but thinend soor my that a's
# ASrestomen live.
#
# BUCKINGURD:
# GLABdoby Rurtharentines?
# To,
# And ways siruli's dodel fould, lettizlespr.
#
# OLIUS:
# No Ceand the crasst murly
# Ard to for, peccac
#
# Iteration: 815000, Loss: 45.2519
# Sample: her's mike, oke and your for they for whom spiebly awn wis Etpor him doe,
# He wor rimlysed, pour to metow?' Eded nad, eardinep,
# Pleangre:
# I omit.
#
# Oro kequirer.
# They everer are.
#
# BAPl Cad hourss coms;
#
#
# Iteration: 815500, Loss: 47.2033
# Sample:  with it mandt: I
# Ell briobln,
# And unds and youclle the muge Mortonfelf griefod shillout to luat
# erven.
#
# So kit sovery, farscame deenst lore ther the vacit; and hid thome Is yelcul, Dyond with word th
#
# Iteration: 816000, Loss: 47.8550
# Sample: ry the my righas.
#
# Petiebuse thou her fro the frermwnow the blood,
# wLece art ard woy trame of furds.
# Buiged cong tuw, reard's od as exearbn aine sin al doth tyou in to oogeest and it thour winged then
#
# Iteration: 816500, Loss: 48.4094
# Sample: ouss condaod of shall well oft praise will tryne's of and han, asln ling daind to for my thas mons thot thill Harich a layslarigs.
# Suck or may you gony sayeen thou, they withur wiblosk!
# My creblanges
#
# Iteration: 817000, Loss: 48.3088
# Sample: R ELLIUTER:
# Whyle of compsion, in yous lord;
# Hith, a and unt I not this sige aper
# Thy chatorous thom nime
# Monteet to tite you espusting acks mame,
# Wheh, abe sust thy not saissad king lomesbitree and w
#
# Iteration: 817500, Loss: 48.1523
# Sample: eeftenys llege.
#
# SSICLIS:
# Fir him, dlest sulle,
# The stimentice thou now mue Yeachesy proch on so thou have lowhy nerpsegghast the as the for venped;
# For, littion of or withen to nec afting hin weniunt
